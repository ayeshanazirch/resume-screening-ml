# %%
# !pip install PyPDF2 pandas scikit-learn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 3.0 MB/s eta 0:00:00
# ...

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-75e377c6-4d1b-44cc-a98f-31595df4f917" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-75e377c6-4d1b-44cc-a98f-31595df4f917">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'AyeshaNazir_resume.pdf', 'sample_data']

# %%
import PyPDF2

def extract_text_from_pdf(pdf_path):
    reader = PyPDF2.PdfReader(pdf_path)
    text = ""

    for page in reader.pages:
        text += page.extract_text()

    return text

# Replace with your actual file name
text = extract_text_from_pdf("AyeshaNazir_resume.pdf")
print(text)
# Out:
# Ayesha Nazir
# Computer Scientist
# ayeshanazirch@gmail.com 923704212755 lahore, pakistan
# Jan 2024 -Jun 2024
# Nov 2022 -Feb 2023
# Jan 2024 -Oct 2024
# Feb 2022 -Jul2022WORK EXPERIENCE
# Associate Lecturer
# University of Central Punjab
# Accomplishments / Tasks
# Worked as lecturer in ACT dept. teaching subject of
# discrete structures and conducting ICT labs
# Lecturer
# Govt. Post Graduate College for women
# Accomplishments / Tasks
# Successfully taught subjects of computer science
# Software Developer
# Software Company
# Accomplishments / Tasks
# Developed and maintained backend applications
# using Node.js, Express.js, and NestJS .
# Lecturer
# University of the Punjab
# |
# gujranwala
# Accomplishments / Tasks
# successfully taught subjects and took labs of web
# engineering and digital logic design
# HR manager
# software company
# |
# lahore
# Nov 2017 -Aug 2021
# Nov 2021 -Mar 2023EDUCA TION
# BSCS
# University of Central Punjab
# |
# 3.55
# MSCS
# ...

# %%
job_description = """
AI developer required with Python skills and machine learning experience.
"""

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def similarity_score(resume_text, job_description):
    vectorizer = TfidfVectorizer()
    vectors = vectorizer.fit_transform([resume_text, job_description])

    similarity = cosine_similarity(vectors[0], vectors[1])[0][0]

    return similarity * 100

score = similarity_score(text, job_description)
print("Match Score:", score)
# Out:
# Match Score: 8.931652325987109
